# %%
"""
The simplest thing we require from a programming language is:
1. it should take some input and
2. give some output
"""

# %%
name = input("Enter your name: ") # Here, The text quoted inside the input() function is
print("Hello World!")
print("This is", name)
# Out:
# Enter your name: Kumar Abhishek
# Hello World!
# This is Kumar Abhishek

# %% [markdown]
# ![image.png](attachment:image.png)
